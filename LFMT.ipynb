# %%
from codes.construction_bases import *
from codes.fonctions_auxiliaires import *
from codes.classes import *
from codes.calculs import *
from codes.affichages import *

# %%
data = charge_fichier('data/LFMT.data')
metars = build_dict_metar('data/LFMT.txt')

# %%
rose_des_vents(data)

# %%
plot_weather(metars,seuil=2)

# %%
trace_phenomene(metars,'FG')

# %%
trace_phenomene(metars,'BR')

# %%
trace_phenomene(metars,'TS')

# %%
trace_tableau_temp(data)

# %%
trace_tableau_gel(data)

# %%
trace_tableau_qnh(data)

# %%
trace_tableau_precipitation(data)

# %%
trace_tableau_vent_travers(data,12)

# %%
trace_tableau_vent_effectif(data,12)

# %%
acft = avion('TRIN')
ad = aerodrome('LFMT')
trace_limitations(data,acft,ad,30)

# %%
trace_donnees_manquantes(data)

# %%
affiche_tc_visi_plafond(data)
